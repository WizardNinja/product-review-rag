# %%
from dotenv import load_dotenv
load_dotenv()
from product_rag_system import load_reviews, create_documents, create_vector_store, query_product

# %%
# only run this if vectorstore has not already been created
df = load_reviews('example_reviews.csv')
documents = create_documents(df)
vectorstore = create_vector_store(documents)

# %%
results = query_product("What could be better about this product?", "B003B3OOPA")
print(results)
# Out:
# Based on the customer reviews, there are a few areas where the product could be improved:
#
# 1. **Taste and Flavor**: Several customers expressed that the product does not have as much taste as they had hoped for. For instance, one reviewer mentioned, "this product is good but doesn't quite have as much taste as I had hoped for," indicating a desire for a more flavorful experience. This sentiment was echoed in another review with the same wording.
#
# 2. **Thickness**: One customer specifically noted that they expected the product to be thicker, suggesting that a thicker consistency might enhance their experience. This feedback indicates that some users may prefer a more substantial texture.
#
# 3. **Price**: While many reviews praised the product's quality, a couple of customers mentioned that it is "a bit on the expensive side." This suggests that while the product is appreciated, some customers might be looking for a more budget-friendly option.
#
# ...
